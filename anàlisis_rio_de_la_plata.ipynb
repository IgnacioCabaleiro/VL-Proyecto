# %% [markdown]
# Se instalan aquellas dependencias necesarias:

# %%
# %pip install ipywidgets
# %pip install ydata-profiling
# Out:
# Requirement already satisfied: ipywidgets in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (8.1.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipywidgets) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipywidgets) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipywidgets) (5.10.1)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: backcall in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python311\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\pc\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\pc\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\pc\appdata\roaming\python\python311\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ydata-profiling in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (4.8.3)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.11.3)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (2.1.3)
# Requirement already satisfied: matplotlib<3.9,>=3.2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (3.8.1)
# Requirement already satisfied: pydantic>=2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (2.5.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (6.0.1)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (3.1.2)
# Requirement already satisfied: visions<0.7.7,>=0.7.5 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2,>=1.16.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (4.66.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.13.0)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.11.2)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.14.0)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (4.3.0)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: dacite>=1.8 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (1.8.1)
# Requirement already satisfied: numba<1,>=0.56.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from ydata-profiling) (0.59.1)
# Requirement already satisfied: PyWavelets in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.6.0)
# Requirement already satisfied: pillow in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (4.44.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\pc\appdata\roaming\python\python311\site-packages (from matplotlib<3.9,>=3.2->ydata-profiling) (2.8.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from numba<1,>=0.56.0->ydata-profiling) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.3.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2->ydata-profiling) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2->ydata-profiling) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.3)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python311\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\pc\appdata\local\programs\python\python311\lib\site-packages (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling) (3.2.1)
# Requirement already satisfied: six in c:\users\pc\appdata\roaming\python\python311\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata-profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Importamos las librerias necesarias para el análisis.

# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# %matplotlib inline
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_5500\3474515570.py:2: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   import pandas_profiling as pp

# %%
df = pd.read_csv("datos_rio.csv", sep=';')

# %% [markdown]
# Para poder observar mejor los datos:

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %%
df.head(5)
# Out:
#    orden                                 sitios codigo       fecha   año  \
# 0      1           Canal Villanueva y Río Luján  TI001  2023-02-22  2023
# 1      2           Río Lujan y Arroyo Caraguatá  TI006  2023-02-22  2023
# 2      3            Canal Aliviador y Río Lujan  TI002  2023-02-22  2023
# 3      4  Río Carapachay y Arroyo Gallo Fiambre  TI003  2023-02-22  2023
# 4      5            Río Reconquista y Río Lujan  TI004  2023-02-22  2023
#
#   campaña  tem_agua  tem_aire    od    ph    olores      color   espumas  \
# 0  Verano      26.0      24.0  6.59  7.24  Ausencia   Ausencia  Ausencia
# 1  Verano      26.8      25.0  5.94  6.96  Ausencia   Ausencia  Ausencia
# 2  Verano      27.6      24.0  6.14  6.88  Ausencia   Ausencia  Ausencia
# 3  Verano      26.1      25.0  5.02  6.82  Ausencia   Ausencia  Ausencia
# 4  Verano      25.9      24.0  5.28  6.69  Ausencia  Presencia  Ausencia
#
#     mat_susp  colif_fecales_ufc_100ml  escher_coli_ufc_100ml  \
# 0  Presencia                    600.0                  100.0
# 1  Presencia                   1000.0                  400.0
# 2  Presencia                   2000.0                 1000.0
# 3  Presencia                   6000.0                  500.0
# 4  Presencia                  15000.0                 3200.0
#
#    enteroc_ufc_100ml  nitrato_mg_l  nh4_mg_l  p_total_l_mg_l  \
# 0              130.0           3.9      0.05            0.26
# 1                1.5           5.2      0.25            0.16
# 2              100.0           3.5      2.20            0.41
# 3              220.0           3.9      0.56            0.23
# 4              560.0           4.3      1.50            0.44
#
#    fosf_ortofos_mg_l  dbo_mg_l  dqo_mg_l  turbiedad_ntu  hidr_deriv_petr_ug_l  \
# 0               0.10       2.0      30.0           29.0                   0.1
# 1               0.11       2.1      30.0           24.0                   0.1
# 2               0.36       4.1      30.0           21.0                   0.1
# 3               0.17       2.2      30.0           28.0                   0.1
# 4               0.25       3.3      30.0           24.0                   0.1
#
#    cr_total_mg_l  cd_total_mg_l  clorofila_a_ug_l  microcistina_ug_l   ica  \
# 0          0.005          0.001              0.87               0.15  53.0
# 1          0.005          0.001             10.61               0.21  39.0
# 2          0.005          0.001             16.87               2.98  35.0
# 3          0.005          0.001             10.89               0.15  37.0
# 4          0.005          0.001              8.57               0.15  34.0
#
#               calidad_de_agua
# 0            Muy deteriorada
# 1  Extremadamente deteriorada
# 2  Extremadamente deteriorada
# 3  Extremadamente deteriorada
# 4  Extremadamente deteriorada

# %% [markdown]
# En las columnas: "nitrato_mg_l", "nh4_mg_l", "p_total_l_mg_l", "fosf_ortofos_mg_l", "dbo_mg_l", "dqo_mg_l", "hidr_deriv_petr_ug_l", "cr_total_mg_l", "cd_total_mg_l", "clorofila_a_ug_l" y "microcistina_ug_l" hay datos del estilo "<0.05" por lo tanto vamos a eliminar el < asi podemos tratarlos como números.

# %%
columns_to_convert = ["nitrato_mg_l", "nh4_mg_l", "p_total_l_mg_l", "fosf_ortofos_mg_l", "dbo_mg_l", "dqo_mg_l", "hidr_deriv_petr_ug_l", "cr_total_mg_l", "cd_total_mg_l", "clorofila_a_ug_l" , "microcistina_ug_l"]

# %%
def handle_less_or_greater_than(value):
    if isinstance(value, str):
        if value.startswith('<'):
            try:
                return float(value[1:])
            except ValueError:
                return np.nan
        elif value.startswith('>'):
            try:
                return float(value[1:])
            except ValueError:
                return np.nan
    return value
for column in columns_to_convert:
    df[column] = df[column].apply(handle_less_or_greater_than)

# %% [markdown]
# Se observa el % de datos nulos dentro del dataset.

# %%
total_rows = df.shape[0]
null_percentage_df = pd.DataFrame()
null_percentage_df = (df.isnull().sum() / total_rows*100 ).reset_index()
null_percentage_df.columns = ['Variables','%']
null_percentage_df
# Out:
#                   Variables         %
# 0                     orden  0.000000
# 1                    sitios  0.000000
# 2                    codigo  0.000000
# 3                     fecha  0.000000
# 4                       año  0.000000
# 5                   campaña  0.000000
# 6                  tem_agua  0.000000
# 7                  tem_aire  0.000000
# 8                        od  0.000000
# 9                        ph  0.591716
# 10                   olores  0.000000
# 11                    color  0.000000
# 12                  espumas  0.000000
# 13                 mat_susp  0.000000
# 14  colif_fecales_ufc_100ml  0.000000
# 15    escher_coli_ufc_100ml  0.000000
# 16        enteroc_ufc_100ml  0.000000
# 17             nitrato_mg_l  0.000000
# 18                 nh4_mg_l  0.000000
# 19           p_total_l_mg_l  0.591716
# 20        fosf_ortofos_mg_l  0.000000
# 21                 dbo_mg_l  0.591716
# 22                 dqo_mg_l  0.000000
# 23            turbiedad_ntu  0.000000
# 24     hidr_deriv_petr_ug_l  0.000000
# 25            cr_total_mg_l  0.000000
# 26            cd_total_mg_l  0.000000
# 27         clorofila_a_ug_l  0.000000
# 28        microcistina_ug_l  0.000000
# 29                      ica  0.591716
# 30          calidad_de_agua  8.875740

# %% [markdown]
# Hay muchos datos que en vez de ser nulos directamente, aparecen con palabras del estilo: "no se midió","falto un frasco","no se pudo calcular". Por lo tanto, se los va a considerar como datos nulos también.

# %%
null_words = ["no se muestréo","no se muestreó","sin muestra","envase sin muestra","sin equipo","en obra","no se midió","falto un frasco","no se pudo calcular","no muestréo","no muestreó","inaccesible"]

def replace_with_nan(df, words):
    for word in words:
        df = df.applymap(lambda x: np.nan if isinstance(x, str) and word in x else x)
    return df

df = replace_with_nan(df, null_words)
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_3936\2993214595.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: np.nan if isinstance(x, str) and word in x else x)

# %%
df.dtypes
# Out:
# orden                       int64
# sitios                     object
# codigo                     object
# fecha                      object
# año                         int64
# campaña                    object
# tem_agua                   object
# tem_aire                   object
# od                         object
# ph                         object
# olores                     object
# color                      object
# espumas                    object
# mat_susp                   object
# colif_fecales_ufc_100ml    object
# escher_coli_ufc_100ml      object
# enteroc_ufc_100ml          object
# nitrato_mg_l               object
# nh4_mg_l                   object
# p_total_l_mg_l             object
# fosf_ortofos_mg_l          object
# dbo_mg_l                   object
# dqo_mg_l                   object
# turbiedad_ntu              object
# hidr_deriv_petr_ug_l       object
# cr_total_mg_l              object
# cd_total_mg_l              object
# clorofila_a_ug_l           object
# microcistina_ug_l          object
# ica                        object
# calidad_de_agua            object
# dtype: object

# %% [markdown]
# Convertimos todos los tipos de datos correspondiente a numeros a int. Ya que como en el dataset anterior, son "object" la mayoria de ellos.

# %%
columns_to_convert = [
    'tem_agua', 'tem_aire', 'od', 'ph', 'colif_fecales_ufc_100ml',
    'escher_coli_ufc_100ml', 'enteroc_ufc_100ml', 'nitrato_mg_l', 'nh4_mg_l',
    'p_total_l_mg_l', 'fosf_ortofos_mg_l', 'dbo_mg_l', 'dqo_mg_l',
    'turbiedad_ntu','hidr_deriv_petr_ug_l', 'cr_total_mg_l','cd_total_mg_l',
    'clorofila_a_ug_l', 'microcistina_ug_l', 'ica'
]

for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce')

# %%
df["fecha"] = pd.to_datetime(df["fecha"]).dt.date
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_5500\2509139177.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["fecha"] = pd.to_datetime(df["fecha"]).dt.date

# %% [markdown]
# Ahora se ve más cantidad de nulos en el dataset.

# %%
total_rows = df.shape[0]
null_percentage_df = pd.DataFrame()
null_percentage_df = (df.isnull().sum() / total_rows*100 ).reset_index()
null_percentage_df.columns = ['Variables','%']
null_percentage_df
# Out:
#                   Variables          %
# 0                     orden   0.000000
# 1                    sitios   0.000000
# 2                    codigo   0.000000
# 3                     fecha   0.000000
# 4                       año   0.000000
# 5                   campaña   0.000000
# 6                  tem_agua  18.343195
# 7                  tem_aire  15.976331
# 8                        od  21.301775
# 9                        ph  26.035503
# 10                   olores   0.000000
# 11                    color   0.000000
# 12                  espumas   0.000000
# 13                 mat_susp   0.000000
# 14  colif_fecales_ufc_100ml  14.792899
# 15    escher_coli_ufc_100ml  14.792899
# 16        enteroc_ufc_100ml  14.792899
# 17             nitrato_mg_l  10.650888
# 18                 nh4_mg_l  10.650888
# 19           p_total_l_mg_l  11.242604
# 20        fosf_ortofos_mg_l  13.017751
# 21                 dbo_mg_l  11.242604
# 22                 dqo_mg_l  10.650888
# 23            turbiedad_ntu  10.650888
# 24     hidr_deriv_petr_ug_l  11.242604
# 25            cr_total_mg_l  10.650888
# 26            cd_total_mg_l  10.650888
# 27         clorofila_a_ug_l  12.426036
# 28        microcistina_ug_l  12.426036
# 29                      ica  18.934911
# 30          calidad_de_agua   8.875740

# %% [markdown]
# En el siguiente gráfico se ven todos los datos faltantes. Para facilitar la predicción se eliminarán.

# %%
sns.barplot(x = 'Variables',y = '%',data = null_percentage_df, palette = 'muted')
plt.xticks(rotation=90)
plt.title("Porcentaje de valores faltantes")
plt.xlabel('Variables')
plt.ylabel('Porcentaje')
plt.show()
# Out:
# C:\Users\Pc\AppData\Local\Temp\ipykernel_5500\1781208138.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = 'Variables',y = '%',data = null_percentage_df, palette = 'muted')

# %%
df = df.dropna()

# %%
df.dtypes
# Out:
# orden                        int64
# sitios                      object
# codigo                      object
# fecha                       object
# año                          int64
# campaña                     object
# tem_agua                   float64
# tem_aire                   float64
# od                         float64
# ph                         float64
# olores                      object
# color                       object
# espumas                     object
# mat_susp                    object
# colif_fecales_ufc_100ml    float64
# escher_coli_ufc_100ml      float64
# enteroc_ufc_100ml          float64
# nitrato_mg_l               float64
# nh4_mg_l                   float64
# p_total_l_mg_l             float64
# fosf_ortofos_mg_l          float64
# dbo_mg_l                   float64
# dqo_mg_l                   float64
# turbiedad_ntu              float64
# hidr_deriv_petr_ug_l       float64
# cr_total_mg_l              float64
# cd_total_mg_l              float64
# clorofila_a_ug_l           float64
# microcistina_ug_l          float64
# ica                        float64
# calidad_de_agua             object
# dtype: object

# %% [markdown]
# Se observan algunos datos "object" todavia. Primero se los pasara a string y luego finalmente se hara dummie esa variable. Es decir, se va a crear una columna booleana por cada valor posible de la columna original.

# %%
df = df.astype({col: 'string' for col in df.select_dtypes(include='object').columns})

# %% [markdown]
# Los siguientes datos no son de ninguna importancia ni tienen un peso importante para predecir. Por lo tanto, se los elimina.

# %%
df = df.drop(["fecha","codigo","orden"],axis=1)

# %%
df_dummies = pd.get_dummies(df, columns=df.select_dtypes(include='string').columns)

# %%
print("Cantidad de columnas antes:",df.shape[1])
print("Cantidad de columnas despues:",df_dummies.shape[1])
df_dummies
# Out:
# Cantidad de columnas antes: 28
# Cantidad de columnas despues: 70
#       año  tem_agua  tem_aire    od    ph  colif_fecales_ufc_100ml  \
# 0    2023      26.0      24.0  6.59  7.24                    600.0
# 1    2023      26.8      25.0  5.94  6.96                   1000.0
# 2    2023      27.6      24.0  6.14  6.88                   2000.0
# 3    2023      26.1      25.0  5.02  6.82                   6000.0
# 4    2023      25.9      24.0  5.28  6.69                  15000.0
# ..    ...       ...       ...   ...   ...                      ...
# 153  2023      22.0      22.0  5.55  7.41                   2400.0
# 165  2023      23.0      21.0  7.51  8.02                  52000.0
# 166  2023      24.0      20.0  4.53  7.84                  81000.0
# 167  2023      20.0      20.0  9.78  8.49                   1000.0
# 168  2023      20.0      14.0  8.22  8.30                    800.0
#
#      escher_coli_ufc_100ml  enteroc_ufc_100ml  nitrato_mg_l  nh4_mg_l  \
# 0                    100.0              130.0           3.9      0.05
# 1                    400.0                1.5           5.2      0.25
# 2                   1000.0              100.0           3.5      2.20
# 3                    500.0              220.0           3.9      0.56
# 4                   3200.0              560.0           4.3      1.50
# ..                     ...                ...           ...       ...
# 153                 1800.0              330.0           2.8      1.90
# 165                15600.0             1960.0           2.9      2.10
# 166                75000.0            18400.0           2.0     11.00
# 167                  800.0              850.0           2.0      0.33
# 168                  800.0              360.0           4.1      0.39
#
#      p_total_l_mg_l  fosf_ortofos_mg_l  dbo_mg_l  dqo_mg_l  turbiedad_ntu  \
# 0              0.26               0.10       2.0      30.0           29.0
# 1              0.16               0.11       2.1      30.0           24.0
# 2              0.41               0.36       4.1      30.0           21.0
# 3              0.23               0.17       2.2      30.0           28.0
# 4              0.44               0.25       3.3      30.0           24.0
# ..              ...                ...       ...       ...            ...
# 153            0.27               0.20       3.8      80.0           13.0
# 165            0.44               0.20       4.1      65.0           70.0
# 166            0.96               0.51      23.0      86.0           50.0
# 167            0.38               0.20       2.2      77.0           34.0
# 168            0.21               0.20       2.0      48.0          110.0
#
#      hidr_deriv_petr_ug_l  cr_total_mg_l  cd_total_mg_l  clorofila_a_ug_l  \
# 0                     0.1          0.005          0.001              0.87
# 1                     0.1          0.005          0.001             10.61
# 2                     0.1          0.005          0.001             16.87
# 3                     0.1          0.005          0.001             10.89
# 4                     0.1          0.005          0.001              8.57
# ..                    ...            ...            ...               ...
# 153                   0.1          0.005          0.001             10.00
# 165                   0.1          0.005          0.001             10.00
# 166                   0.1          0.005          0.001             10.00
# 167                   0.1          0.005          0.001             10.00
# 168                   0.1          0.000          0.001             37.40
#
#      microcistina_ug_l   ica  sitios_Arroyo Abra Vieja y Santa Rosa  \
# 0                 0.15  53.0                                  False
# 1                 0.21  39.0                                  False
# 2                 2.98  35.0                                  False
# 3                 0.15  37.0                                  False
# 4                 0.15  34.0                                  False
# ..                 ...   ...                                    ...
# 153               0.15  40.0                                  False
# 165               1.18  37.0                                  False
# 166               0.15  25.0                                  False
# 167               0.15  41.0                                  False
# 168               0.15  35.0                                  False
#
#      sitios_Arroyo El Gato  sitios_Arroyo Santo Domingo  \
# 0                    False                        False
# 1                    False                        False
# 2                    False                        False
# 3                    False                        False
# 4                    False                        False
# ..                     ...                          ...
# 153                  False                        False
# 165                  False                        False
# 166                  False                        False
# 167                  False                        False
# 168                  False                        False
#
#      sitios_Arroyo Sarandí  sitios_Balneario Municipal  \
# 0                    False                       False
# 1                    False                       False
# 2                    False                       False
# 3                    False                       False
# 4                    False                       False
# ..                     ...                         ...
# 153                  False                       False
# 165                  False                       False
# 166                  False                       False
# 167                  False                        True
# 168                  False                       False
#
#      sitios_Balneario Palo Blanco  sitios_Camping Eva Perón  \
# 0                           False                     False
# 1                           False                     False
# 2                           False                     False
# 3                           False                     False
# 4                           False                     False
# ..                            ...                       ...
# 153                         False                     False
# 165                         False                     False
# 166                         False                     False
# 167                         False                     False
# 168                         False                     False
#
#      sitios_Canal Aliviador y Río Lujan  sitios_Canal Villanueva y Río Luján  \
# 0                                 False                                 True
# 1                                 False                                False
# 2                                  True                                False
# 3                                 False                                False
# 4                                 False                                False
# ..                                  ...                                  ...
# 153                               False                                False
# 165                               False                                False
# 166                               False                                False
# 167                               False                                False
# 168                               False                                False
#
#      sitios_Club de Pescadores  sitios_Costa de Villa Domínico  \
# 0                        False                           False
# 1                        False                           False
# 2                        False                           False
# 3                        False                           False
# 4                        False                           False
# ..                         ...                             ...
# 153                      False                           False
# 165                      False                           False
# 166                      False                           False
# 167                      False                           False
# 168                      False                           False
#
#      sitios_Costa y Melo  sitios_Costanera Norte - Espigón Abanico  \
# 0                  False                                     False
# 1                  False                                     False
# 2                  False                                     False
# 3                  False                                     False
# 4                  False                                     False
# ..                   ...                                       ...
# 153                False                                     False
# 165                False                                     False
# 166                False                                     False
# 167                False                                     False
# 168                False                                     False
#
#      sitios_Diagonal 66 (descarga cloaca)  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ..                                    ...
# 153                                 False
# 165                                  True
# 166                                 False
# 167                                 False
# 168                                 False
#
#      sitios_Ensenada Prefectura Isla Santiago  sitios_Escollera de Propaneros  \
# 0                                       False                           False
# 1                                       False                           False
# 2                                       False                           False
# 3                                       False                           False
# 4                                       False                           False
# ..                                        ...                             ...
# 153                                     False                           False
# 165                                     False                           False
# 166                                     False                           False
# 167                                     False                           False
# 168                                     False                           False
#
#      sitios_Espora 400 m  sitios_Náutico 400 m  sitios_Pejerrey Club 400 m  \
# 0                  False                 False                       False
# 1                  False                 False                       False
# 2                  False                 False                       False
# 3                  False                 False                       False
# 4                  False                 False                       False
# ..                   ...                   ...                         ...
# 153                 True                 False                       False
# 165                False                 False                       False
# 166                False                 False                       False
# 167                False                 False                       False
# 168                False                 False                       False
#
#      sitios_Playa Espigón de Pacheco  sitios_Playa La Bagliardi  \
# 0                              False                      False
# 1                              False                      False
# 2                              False                      False
# 3                              False                      False
# 4                              False                      False
# ..                               ...                        ...
# 153                            False                      False
# 165                            False                      False
# 166                            False                       True
# 167                            False                      False
# 168                            False                      False
#
#      sitios_Playa La Balandra  sitios_Polo Petroquímico Dock Sud  \
# 0                       False                              False
# 1                       False                              False
# 2                       False                              False
# 3                       False                              False
# 4                       False                              False
# ..                        ...                                ...
# 153                     False                              False
# 165                     False                              False
# 166                     False                              False
# 167                     False                              False
# 168                      True                              False
#
#      sitios_Puerto de Olivos Espigón  sitios_Reserva Barrio El Ceibo  \
# 0                              False                           False
# 1                              False                           False
# 2                              False                           False
# 3                              False                           False
# 4                              False                           False
# ..                               ...                             ...
# 153                            False                           False
# 165                            False                           False
# 166                            False                           False
# 167                            False                           False
# 168                            False                           False
#
#      sitios_Reserva Ecológica  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 153                     False
# 165                     False
# 166                     False
# 167                     False
# 168                     False
#
#      sitios_Reserva Ecológica Costanera Sur - Playita  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ..                                                ...
# 153                                             False
# 165                                             False
# 166                                             False
# 167                                             False
# 168                                             False
#
#      sitios_Rio Tigre 100m antes del Rio Luján  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ..                                         ...
# 153                                      False
# 165                                      False
# 166                                      False
# 167                                      False
# 168                                      False
#
#      sitios_Río Capitán y Río San Antonio  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
# ..                                    ...
# 153                                 False
# 165                                 False
# 166                                 False
# 167                                 False
# 168                                 False
#
#      sitios_Río Carapachay y Arroyo Gallo Fiambre  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
# ..                                            ...
# 153                                         False
# 165                                         False
# 166                                         False
# 167                                         False
# 168                                         False
#
#      sitios_Río Lujan y Arroyo Caraguatá  \
# 0                                  False
# 1                                   True
# 2                                  False
# 3                                  False
# 4                                  False
# ..                                   ...
# 153                                False
# 165                                False
# 166                                False
# 167                                False
# 168                                False
#
#      sitios_Río Lujan y Canal San Fernando  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 153                                  False
# 165                                  False
# 166                                  False
# 167                                  False
# 168                                  False
#
#      sitios_Río Reconquista y Río Lujan  sitios_Toma de agua Club de Pesca  \
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
# 3                                 False                              False
# 4                                  True                              False
# ..                                  ...                                ...
# 153                               False                              False
# 165                               False                              False
# 166                               False                              False
# 167                               False                              False
# 168                               False                              False
#
#      campaña_Verano  campaña_invierno  campaña_otoño  campaña_primavera  \
# 0              True             False          False              False
# 1              True             False          False              False
# 2              True             False          False              False
# 3              True             False          False              False
# 4              True             False          False              False
# ..              ...               ...            ...                ...
# 153           False             False          False               True
# 165           False             False          False               True
# 166           False             False          False               True
# 167           False             False          False               True
# 168           False             False          False               True
#
#      olores_Ausencia  olores_Presencia  color_Ausencia  color_Presencia  \
# 0               True             False            True            False
# 1               True             False            True            False
# 2               True             False            True            False
# 3               True             False            True            False
# 4               True             False           False             True
# ..               ...               ...             ...              ...
# 153             True             False            True            False
# 165             True             False            True            False
# 166            False              True            True            False
# 167             True             False            True            False
# 168             True             False            True            False
#
#      espumas_Ausencia  espumas_Presencia  mat_susp_Ausencia  \
# 0                True              False              False
# 1                True              False              False
# 2                True              False              False
# 3                True              False              False
# 4                True              False              False
# ..                ...                ...                ...
# 153              True              False               True
# 165              True              False               True
# 166             False               True              False
# 167              True              False               True
# 168              True              False              False
#
#      mat_susp_Presencia  calidad_de_agua_Extremadamente deteriorada  \
# 0                  True                                       False
# 1                  True                                        True
# 2                  True                                        True
# 3                  True                                        True
# 4                  True                                        True
# ..                  ...                                         ...
# 153               False                                        True
# 165               False                                        True
# 166                True                                        True
# 167               False                                        True
# 168                True                                        True
#
#      calidad_de_agua_Muy deteriorada  calidad_de_agua_Muy deteriorada
# 0                              False                              True
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
# ..                               ...                               ...
# 153                            False                             False
# 165                            False                             False
# 166                            False                             False
# 167                            False                             False
# 168                            False                             False
#
# [87 rows x 70 columns]

# %% [markdown]
# Ahora dividimos el set de datos en un df para entrenar y otro para predecir. Se va a testear el modelo con un 20% del dataset original. Como columna a predecir va a quedar "ica", el índice de calidad del agua.

# %%
target_name = "ica"
Y = df_dummies[target_name]
X = df_dummies.drop([target_name],axis=1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %% [markdown]
# Ahora se va a entrenar y predecir con dos modelos simples. El primero es el DecisionTreeClasifier. Donde cada rama del arbol corresponde a uno de los posibles valores para cada atributo.

# %%
tree_model = tree.DecisionTreeClassifier(max_depth = 20,
                                         min_samples_leaf = 15)

model = tree_model.fit(X = x_train, y = y_train)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([37., 40., 40., 40., 40., 40., 37., 37., 37., 40., 37., 37., 39.,
#        39., 40., 37., 37., 39.])

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Squared Error: 13.61111111111111
# Root Mean Squared Error (RMSE): 3.689323936863109

# %% [markdown]
# El segundo es un modelo de regresión lineal que lo que hace es predecir en base a una linea recta trazada diagonalmente en un eje cartesiano y la correlación de los datos (puntos en el gráfico) entre si y con la recta.

# %%
model = LinearRegression()

model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([45.8734394 , 41.95764487, 63.8747905 , 54.69324055, 32.84110582,
#        40.25594592, 42.33126952, 32.19062418, 35.21660863, 42.44502007,
#        43.50033907, 38.83167522, 46.92644454, 40.75933985, 37.90997846,
#        40.19084918, 33.24220115, 35.64446208])

# %%
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# Mean Squared Error: 58.92995551053629
# Root Mean Squared Error (RMSE): 7.676584885907032

# %% [markdown]
# Como resultados se obtuvo en el árbol de decisión un RMSE de 3.689323936863109 y en el modelo de regresión logistica un RMSE de 7.676584885907032. Este tipo de medición nos sirve para interpretar en las mismas unidades que la variable que esta prediciendo. Mientras más bajo sea el valor de RMSE, mejor será el rendimiento del modelo en términos de precisión de las predicciones. Por lo tanto puedo determinar que en la comparación entre estos dos modelos simple, el *árbol de decisión* predijo mejor.
